# %%
# %matplotlib widget
from easydynamics.analysis import Analysis


from easydynamics.sample import GaussianComponent
from easydynamics.sample import LorentzianComponent
from easydynamics.sample import PolynomialComponent
from easydynamics.sample import SampleModel
from easydynamics.sample import DeltaFunctionComponent

from easydynamics.experiment  import Experiment

from easydynamics.job import Job
from easydynamics.experiment  import Data

import matplotlib.pyplot as plt
import scipp as sc
import plopp as pp
plt.close()

# %%
MyJob= Job(name='Vanadium sample')

theory= SampleModel('Vanadium Model')
theory.add_component(GaussianComponent(width=0.5e-3,area=5e-5,name='resGauss'))
theory.add_component(LorentzianComponent(width=2e-3, area=2e-6,name='resLorz'))

MyJob.set_theory(theory)


experiment=Experiment('Vanadium Experiment')

background=SampleModel('Vanadium Background')
background.add_component(PolynomialComponent(coefficients=[1e-3]))


MyJob.set_background_model(background)
data=Data('Vanadium Data')
data.append(data.load_example_vanadium_data())

experiment.set_data(data)

MyJob.set_experiment(experiment)


analysis=Analysis('Vanadium Analysis')

analysis.set_background_model(background)

analysis.set_resolution_model(None)

# MyJob.set_analysis(analysis)

MyJob.generate_analysis_for_cuts()
# Out:
# Job `Vanadium sample`

# %%
MyJob._analysis
# Out:
# [Analysis `Analysis(0,)`,
#  Analysis `Analysis(1,)`,
#  Analysis `Analysis(2,)`,
#  Analysis `Analysis(3,)`,
#  Analysis `Analysis(4,)`,
#  Analysis `Analysis(5,)`,
#  Analysis `Analysis(6,)`,
#  Analysis `Analysis(7,)`,
#  Analysis `Analysis(8,)`,
#  Analysis `Analysis(9,)`,
#  Analysis `Analysis(10,)`,
#  Analysis `Analysis(11,)`,
#  Analysis `Analysis(12,)`,
#  Analysis `Analysis(13,)`,
#  Analysis `Analysis(14,)`,
#  Analysis `Analysis(15,)`]

# %%
MyJob._analysis[0].get_fit_parameters()
# Out:
# [<Parameter 'resGaussarea': 5.000e-05 meV, bounds=[0.0:inf]>,
#  <Parameter 'resGausswidth': 0.0005 meV, bounds=[0.0:inf]>,
#  <Parameter 'resLorzarea': 2.000e-06 meV, bounds=[0.0:inf]>,
#  <Parameter 'resLorzwidth': 0.0020 meV, bounds=[0.0:inf]>,
#  <Parameter 'Polynomial_c0': 0.0010, bounds=[-inf:inf]>,
#  <Parameter 'offset': 0.0000 meV, bounds=[-inf:inf]>]

# %%
MyJob.fit()
# Out:
# Job `Vanadium sample`

# %%
MyJob.plot_data_and_model()
# Out:
# InteractiveFigure(children=(HBar(), HBar(children=(VBar(children=(Toolbar(children=(ButtonTool(icon='home', la…

# %%
# MyJob.plot_fit_parameters(parameter_name='resGaussarea')

# %%
datajob= Job(name='Sample')


dataexperiment=Experiment('Experiment')
newdata=Data('Data')
newdata.append(newdata.load_example_data_3d())

dataexperiment.set_data(newdata)

datajob.set_experiment(dataexperiment)

Newtheory= SampleModel('Model')
Newtheory.add_component(DeltaFunctionComponent(area=0.01e-3))
Newtheory.add_component(LorentzianComponent(width=2e-3, area=5e-6,name='DataLorentzian'))

datajob.set_theory(Newtheory)

Newbackground=SampleModel('Background')
Newbackground.add_component(PolynomialComponent(coefficients=[1e-3]))


datajob.set_background_model(Newbackground)

datajob.generate_analysis_for_cuts()
# Out:
# Job `Sample`

# %%
print(len(MyJob._analysis))
print(len(datajob._analysis))
# Out:
# 16
# 5

# %%
datajob.use_fit_as_resolution(MyJob)
# Out:
# Job `Sample`

# %%
datajob._analysis[0][0].get_parameters()
# Out:
# [<Parameter 'temperature': -1.0000 K (fixed), bounds=[-inf:inf]>,
#  <Parameter 'DeltaFunctionarea': 1.000e-05 meV, bounds=[0.0:inf]>,
#  <Parameter 'DeltaFunctioncenter': 0.0000 meV (fixed), bounds=[-inf:inf]>,
#  <Parameter 'DataLorentzianarea': 5.000e-06 meV, bounds=[0.0:inf]>,
#  <Parameter 'DataLorentziancenter': 0.0000 meV (fixed), bounds=[-inf:inf]>,
#  <Parameter 'DataLorentzianwidth': 0.0020 meV, bounds=[0.0:inf]>,
#  <Parameter 'temperature': -1.0000 K (fixed), bounds=[-inf:inf]>,
#  <Parameter 'resGaussarea': 0.7767 meV (fixed), bounds=[0.0:inf]>,
#  <Parameter 'resGausscenter': 0.0000 meV (fixed), bounds=[-inf:inf]>,
#  <Parameter 'resGausswidth': 0.0004 meV (fixed), bounds=[0.0:inf]>,
#  <Parameter 'resLorzarea': 0.2233 meV (fixed), bounds=[0.0:inf]>,
#  <Parameter 'resLorzcenter': 0.0000 meV (fixed), bounds=[-inf:inf]>,
#  <Parameter 'resLorzwidth': 0.0003 meV (fixed), bounds=[0.0:inf]>,
#  <Parameter 'temperature': -1.0000 K (fixed), bounds=[-inf:inf]>,
#  <Parameter 'Polynomial_c0': 0.0010, bounds=[-inf:inf]>,
#  <Parameter 'offset': 0.0000 meV, bounds=[-inf:inf]>]

# %%
MyJob._analysis[0].get_parameters()
# Out:
# [<Parameter 'temperature': -1.0000 K (fixed), bounds=[-inf:inf]>,
#  <Parameter 'resGaussarea': 4.157e-05 ± 3.098e-06 meV, bounds=[0.0:inf]>,
#  <Parameter 'resGausscenter': 0.0000 meV (fixed), bounds=[-inf:inf]>,
#  <Parameter 'resGausswidth': 0.0004 ± 0.0000 meV, bounds=[0.0:inf]>,
#  <Parameter 'resLorzarea': 1.195e-05 ± 2.941e-06 meV, bounds=[0.0:inf]>,
#  <Parameter 'resLorzcenter': 0.0000 meV (fixed), bounds=[-inf:inf]>,
#  <Parameter 'resLorzwidth': 0.0003 ± 0.0001 meV, bounds=[0.0:inf]>,
#  <Parameter 'temperature': -1.0000 K (fixed), bounds=[-inf:inf]>,
#  <Parameter 'Polynomial_c0': 0.0003 ± 0.0000, bounds=[-inf:inf]>,
#  <Parameter 'offset': -0.0005 ± 0.0000 meV, bounds=[-inf:inf]>]

# %%
datajob._analysis_meta
# Out:
# {'dims': ('Temperature', 'Q'),
#  'sizes': {'Temperature': 5, 'Q': 16},
#  'keep': ('energy',)}

# %%
datajob.plot_data_and_model(intensity_min=0.0, intensity_max=0.015)
# Out:
# InteractiveFigure(children=(HBar(), HBar(children=(VBar(children=(Toolbar(children=(ButtonTool(icon='home', la…

# %%
# datajob._analysis[0].get_fit_parameters()

# %%
datajob.fit()
# Out:
# Job `Sample`

# %%
datajob.plot_data_and_model(intensity_min=0.0, intensity_max=0.015)
# Out:
# InteractiveFigure(children=(HBar(), HBar(children=(VBar(children=(Toolbar(children=(ButtonTool(icon='home', la…

# %%
pars=datajob._fit_parameters
pars
# Out:
# DataGroup(sizes={'Temperature': 5, 'Q': 16}, keys=[
#     temperature[0]: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     DeltaFunctionarea: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     DeltaFunctioncenter: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     DataLorentzianarea: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     DataLorentziancenter: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     DataLorentzianwidth: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     temperature[1]: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     resGaussarea: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     resGausscenter: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     resGausswidth: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     resLorzarea: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     resLorzcenter: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     resLorzwidth: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     temperature[2]: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     Polynomial_c0: DataGroup(4, {'Temperature': 5, 'Q': 16}),
#     offset: DataGroup(4, {'Temperature': 5, 'Q': 16}),
# ])

# %%
pp.slicer(pars['DataLorentzianwidth']['value'],keep='Q')
# Out:
# InteractiveFigure(children=(HBar(), HBar(children=(VBar(children=(Toolbar(children=(ButtonTool(icon='home', la…

# %%
datajob.plot_fit_parameters(parameter_name='DataLorentzianarea')
# Out:
# InteractiveFigure(children=(HBar(), HBar(children=(VBar(children=(Toolbar(children=(ButtonTool(icon='home', la…

# %%
datajob.plot_fit_parameters(parameter_name='DataLorentzianwidth')
# Out:
# InteractiveFigure(children=(HBar(), HBar(children=(VBar(children=(Toolbar(children=(ButtonTool(icon='home', la…
